# %%
import pandas as pd
fl=pd.read_csv('camera_dataset.csv')
fl.head(5)
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997          1024.0           640.0
# 1        Agfa ePhoto 1680          1998          1280.0           640.0
# 2        Agfa ePhoto CL18          2000           640.0             0.0
# 3        Agfa ePhoto CL30          1999          1152.0           640.0
# 4  Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0               0.0           38.0          114.0                70.0
# 1               1.0           38.0          114.0                50.0
# 2               0.0           45.0           45.0                 0.0
# 3               0.0           35.0           35.0                 0.0
# 4               0.0           43.0           43.0                50.0
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
fl.isna().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          1
# Storage included           2
# Weight (inc. batteries)    2
# Dimensions                 2
# Price                      0
# dtype: int64

# %%
fl=fl.dropna()
fl.isna().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          0
# Storage included           0
# Weight (inc. batteries)    0
# Dimensions                 0
# Price                      0
# dtype: int64

# %%
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1036 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model                    1036 non-null   object
#  1   Release date             1036 non-null   int64
#  2   Max resolution           1036 non-null   float64
#  3   Low resolution           1036 non-null   float64
#  4   Effective pixels         1036 non-null   float64
#  5   Zoom wide (W)            1036 non-null   float64
#  6   Zoom tele (T)            1036 non-null   float64
#  7   Normal focus range       1036 non-null   float64
#  8   Macro focus range        1036 non-null   float64
#  9   Storage included         1036 non-null   float64
#  10  Weight (inc. batteries)  1036 non-null   float64
#  11  Dimensions               1036 non-null   float64
#  12  Price                    1036 non-null   float64
# dtypes: float64(11), int64(1), object(1)
# ...

# %%
fl
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
fl['Max resolution']=fl['Max resolution'].astype(int)

# %%
fl['Low resolution']=fl['Low resolution'].astype(int)

# %%
fl['Effective pixels']=fl['Effective pixels'].astype(int)

# %%
fl['Zoom wide (W)']=fl['Zoom wide (W)'].astype(int)

# %%
fl['Zoom tele (T)']=fl['Zoom tele (T)'].astype(int)

# %%
fl['Normal focus range']=fl['Normal focus range'].astype(int)

# %%
fl['Macro focus range']=fl['Macro focus range'].astype(int)

# %%
fl['Storage included']=fl['Storage included'].astype(int)

# %%
fl['Weight (inc. batteries)']=fl['Weight (inc. batteries)'].astype(int)

# %%
fl['Dimensions']=fl['Dimensions'].astype(int)

# %%
fl['Price']=fl['Price'].astype(int)

# %%
fl
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997            1024             640
# 1           Agfa ePhoto 1680          1998            1280             640
# 2           Agfa ePhoto CL18          2000             640               0
# 3           Agfa ePhoto CL30          1999            1152             640
# 4     Agfa ePhoto CL30 Clik!          1999            1152             640
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001            2048            1024
# 1034         Toshiba PDR-M70          2000            2048            1024
# 1035         Toshiba PDR-M71          2001            2048            1024
# 1036         Toshiba PDR-M81          2001            2400            1200
# 1037         Toshiba PDR-T10          2002            1600             800
#
# ...

# %%
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1036 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model                    1036 non-null   object
#  1   Release date             1036 non-null   int64
#  2   Max resolution           1036 non-null   int64
#  3   Low resolution           1036 non-null   int64
#  4   Effective pixels         1036 non-null   int64
#  5   Zoom wide (W)            1036 non-null   int64
#  6   Zoom tele (T)            1036 non-null   int64
#  7   Normal focus range       1036 non-null   int64
#  8   Macro focus range        1036 non-null   int64
#  9   Storage included         1036 non-null   int64
#  10  Weight (inc. batteries)  1036 non-null   int64
#  11  Dimensions               1036 non-null   int64
#  12  Price                    1036 non-null   int64
# dtypes: int64(12), object(1)
# memory usage: 113.3+ KB

# %%
fl.head()
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997            1024             640
# 1        Agfa ePhoto 1680          1998            1280             640
# 2        Agfa ePhoto CL18          2000             640               0
# 3        Agfa ePhoto CL30          1999            1152             640
# 4  Agfa ePhoto CL30 Clik!          1999            1152             640
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0                 0             38            114                  70
# 1                 1             38            114                  50
# 2                 0             45             45                   0
# 3                 0             35             35                   0
# 4                 0             43             43                  50
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
fl['Model'].unique()
# Out:
# array(['Agfa ePhoto 1280', 'Agfa ePhoto 1680', 'Agfa ePhoto CL18', ...,
#        'Toshiba PDR-M71', 'Toshiba PDR-M81', 'Toshiba PDR-T10'],
#       dtype=object)

# %%
fl=fl.drop(columns='Release date', axis=1)
fl.head()
# Out:
#                     Model  Max resolution  Low resolution  Effective pixels  \
# 0        Agfa ePhoto 1280            1024             640                 0
# 1        Agfa ePhoto 1680            1280             640                 1
# 2        Agfa ePhoto CL18             640               0                 0
# 3        Agfa ePhoto CL30            1152             640                 0
# 4  Agfa ePhoto CL30 Clik!            1152             640                 0
#
#    Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 0             38            114                  70                 40
# 1             38            114                  50                  0
# 2             45             45                   0                  0
# 3             35             35                   0                  0
# 4             43             43                  50                  0
#
#    Storage included  Weight (inc. batteries)  Dimensions  Price
# ...

# %%
kolom=['Model']
onehot= pd.get_dummies(fl[kolom]).astype(int)
fl= pd.concat([fl, onehot], axis=1)

# %%
fl
# Out:
#                        Model  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280            1024             640
# 1           Agfa ePhoto 1680            1280             640
# 2           Agfa ePhoto CL18             640               0
# 3           Agfa ePhoto CL30            1152             640
# 4     Agfa ePhoto CL30 Clik!            1152             640
# ...                      ...             ...             ...
# 1033         Toshiba PDR-M65            2048            1024
# 1034         Toshiba PDR-M70            2048            1024
# 1035         Toshiba PDR-M71            2048            1024
# 1036         Toshiba PDR-M81            2400            1200
# 1037         Toshiba PDR-T10            1600             800
#
#       Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0                    0             38            114                  70
# 1                    1             38            114                  50
# ...

# %%
fl.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1036 entries, 0 to 1037
# Data columns (total 1048 columns):
#  #     Column                                    Dtype
# ---    ------                                    -----
#  0     Model                                     object
#  1     Max resolution                            int64
#  2     Low resolution                            int64
#  3     Effective pixels                          int64
#  4     Zoom wide (W)                             int64
#  5     Zoom tele (T)                             int64
#  6     Normal focus range                        int64
#  7     Macro focus range                         int64
#  8     Storage included                          int64
#  9     Weight (inc. batteries)                   int64
#  10    Dimensions                                int64
#  11    Price                                     int64
#  12    Model_Agfa ePhoto 1280                    int64
# ...

# %%
fl=fl.drop(columns=kolom, axis=1)
fl
# Out:
#       Max resolution  Low resolution  Effective pixels  Zoom wide (W)  \
# 0               1024             640                 0             38
# 1               1280             640                 1             38
# 2                640               0                 0             45
# 3               1152             640                 0             35
# 4               1152             640                 0             43
# ...              ...             ...               ...            ...
# 1033            2048            1024                 3             38
# 1034            2048            1024                 3             35
# 1035            2048            1024                 3             35
# 1036            2400            1200                 3             35
# 1037            1600             800                 1             38
#
#       Zoom tele (T)  Normal focus range  Macro focus range  Storage included  \
# ...

# %%
kolom_swap = 'Price'

kolom = fl.pop(kolom_swap)
fl['Price'] = kolom

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
X = fl.drop(columns=['Price'])
Y = np.log(fl['Price'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.01, random_state=184)
X_train
# Out:
#      Max resolution  Low resolution  Effective pixels  Zoom wide (W)  \
# 275            2832            2048                 3             35
# 72             3264            2272                 8             28
# 998            2816            2048                 6             38
# 580            1984            1600                 3             36
# 530            3264            3200                 8             28
# ..              ...             ...               ...            ...
# 538            2816            2048                 6             38
# 297            3040            2340                 3              0
# 549            2016            1600                 3             37
# 183            2816            2048                 6             39
# 438            3072            2576                 7             23
#
#      Zoom tele (T)  Normal focus range  Macro focus range  Storage included  \
# ...

# %%
fl.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1036 entries, 0 to 1037
# Data columns (total 1047 columns):
#  #     Column                                    Dtype
# ---    ------                                    -----
#  0     Max resolution                            int64
#  1     Low resolution                            int64
#  2     Effective pixels                          int64
#  3     Zoom wide (W)                             int64
#  4     Zoom tele (T)                             int64
#  5     Normal focus range                        int64
#  6     Macro focus range                         int64
#  7     Storage included                          int64
#  8     Weight (inc. batteries)                   int64
#  9     Dimensions                                int64
#  10    Model_Agfa ePhoto 1280                    int64
#  11    Model_Agfa ePhoto 1680                    int64
#  12    Model_Agfa ePhoto CL18                    int64
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
cat = fl.select_dtypes(include = object).columns
cat = cat.tolist()

Encode = ColumnTransformer(transformers=[
    ('Cat', OneHotEncoder(sparse_output=False, drop='first',handle_unknown='ignore', categories='auto'),[0,1,9,10,11] )],remainder='passthrough')

# %%
from xgboost import XGBRegressor

model = XGBRegressor(learning_rate=0.5, n_estimators=100, max_depth=4)

XGBR = Pipeline ([
    ('Encode', Encode),
    ('Model', model)
])

XGBR.fit(X_train,Y_train)
y_pred = XGBR.predict(X_test)
y_pred

from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import r2_score

print('MAE:', MAE(Y_test, y_pred))
print('R2:', r2_score(Y_test, y_pred))

sns.scatterplot(x=Y_test, y=y_pred)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'k-', lw=4)
plt.show()
# Out:
# MAE: 0.22295189130148607
# R2: 0.8616659260514068
